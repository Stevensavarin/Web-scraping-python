# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
def get_title(soup):

    try:
        title = soup.find("span", attrs={"id":'productTitle'})
        title_value = title.text
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string


def get_price(soup):

    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()

    except AttributeError:

        try:
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price


def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating


def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count


def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

# %%
if __name__ == '__main__':

    HEADERS = ({'User-Agent':'', 'Accept-Language': 'en-US, en;q=0.5'})

    URL = "https://www.amazon.com/s?k=gaming+pc&__mk_es_US=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=1XAATVRJOFTMJ&sprefix=gaming+p%2Caps%2C269&ref=nb_sb_noss_2"

    webpage = requests.get(URL, headers=HEADERS)

    soup = BeautifulSoup(webpage.content, "html.parser")

    links = soup.find_all('a', attrs={'class': 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

    links_list = []

    for link in links:
            links_list.append(link.get('href'))

    d = {"title":[], "price":[], "rating":[], "reviews":[],"availability":[]}
    
    for link in links_list:
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        d['title'].append(get_title(new_soup))
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))

    
    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
amazon_df
# Out:
#                                                 title price  \
# 0   STGAubron Gaming Desktop PC, Intel Core I5 3.3...
# 1   STGAubron Gaming Desktop PC,AMD Ryzen 7 5700X ...
# 2   STGAubron Gaming Desktop PC,Intel Core i7 3.4G...
# 3   Skytech Gaming Archangel Gaming PC Desktop – I...
# 4   Skytech Shadow Gaming PC Desktop – AMD Ryzen 7...
# 5   HP Gaming PC Desktop Computer - Intel Quad I5 ...
# 6   Skytech Gaming Nebula Gaming PC Desktop – Inte...
# 7   Skytech Gaming Skytech Archangel Gaming PC Des...
# 8   Skytech Gaming Siege Gaming PC Desktop – Intel...
# 9   Dell RGB Gaming Desktop Computer PC, Intel Cor...
# 10  SAAV T101 Gaming Computer – Powerful, Prebuilt...
# 11  CyberPowerPC Gamer Xtreme VR Gaming PC, Intel ...
# 12  Skytech Gaming Shiva Gaming PC Desktop – Intel...
# 13  STGAubron Gaming Desktop PC,Intel Core i9-1190...
# 14  CyberpowerPC Gamer Xtreme VR Gaming PC, Intel ...
# 15  STGAubron Gaming Desktop,Intel Core i9-11900F ...
# 16  STGAubron Gaming Desktop PC,Intel Core i7-1070...
# 17  ASUS 2023 ROG G22CH DS564 Gaming Desktop PC, S...
# 18  STGAubron Gaming Desktop PC, Intel Core I5 3.3...
# 19  HP RGB Gaming PC Desktop Computer - Intel Quad...
# 20  GAMEPOWER Ravadin ATX Mid-Tower PC Gaming Case...
# 21  Skytech Gaming Shadow Gaming PC Desktop – AMD ...
# 22  MXZ Desktop Gaming Computer Home&Office PC R5 ...
# 23  ViprTech Mutineer Gaming PC Desktop - Intel Co...
# 24  NSXGAMING Nova Desktop Gaming Computer, AMD Ry...
# 25  [Gaming PC] Mini PC Intel 12th i9-12900H 14Cor...
#
#                                          rating        reviews  \
# 0                            3.7 out of 5 stars    247 ratings
# 1                            3.6 out of 5 stars     87 ratings
# 2                            3.6 out of 5 stars     87 ratings
# 3                            4.3 out of 5 stars     22 ratings
# 4                            4.2 out of 5 stars     51 ratings
# 5                            4.1 out of 5 stars     39 ratings
# 6                            4.5 out of 5 stars  2,503 ratings
# 7                            4.4 out of 5 stars    471 ratings
# 8                            4.2 out of 5 stars    396 ratings
# 9                            4.1 out of 5 stars  2,751 ratings
# 10                           3.7 out of 5 stars     12 ratings
# 11                           4.5 out of 5 stars     44 ratings
# 12                           4.4 out of 5 stars     39 ratings
# 13                           3.6 out of 5 stars    356 ratings
# 14                           4.6 out of 5 stars    990 ratings
# 15                           3.8 out of 5 stars    391 ratings
# 16                           3.0 out of 5 stars    160 ratings
# 17  Previous page of related Sponsored Products
# 18                           3.7 out of 5 stars    247 ratings
# 19                           3.6 out of 5 stars     76 ratings
# 20  Previous page of related Sponsored Products
# 21                           4.3 out of 5 stars    462 ratings
# 22                           4.5 out of 5 stars     37 ratings
# 23                           3.9 out of 5 stars     40 ratings
# 24                           4.2 out of 5 stars     10 ratings
# 25                           4.6 out of 5 stars     19 ratings
#
#                                availability
# 0                                  In Stock
# 1                                  In Stock
# 2                                  In Stock
# 3                                  In Stock
# 4                                  In Stock
# 5                                  In Stock
# 6
# 7                                  In Stock
# 8                                  In Stock
# 9                                  In Stock
# 10                                 In Stock
# 11  Only 11 left in stock (more on the way)
# 12                                 In Stock
# 13                                 In Stock
# 14                                 In Stock
# 15                                 In Stock
# 16                                 In Stock
# 17                                 In Stock
# 18                                 In Stock
# 19                                 In Stock
# 20                                 In Stock
# 21                                 In Stock
# 22                                 In Stock
# 23                                 In Stock
# 24                                 In Stock
# 25        Only 7 left in stock - order soon
